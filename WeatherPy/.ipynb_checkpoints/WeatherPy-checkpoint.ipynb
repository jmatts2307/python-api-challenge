# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Had to create this script since it didn't want to read the original starter code file path
# to export and save
import os
if not os.path.exists("output_data"):
    os.makedirs("output_data")


# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#Used an example from class to create this URL, its cleaner and easier to use
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    # Appending each city's name to the query URL, makes an API request for each city
    city_url = f"{query_url}{city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | turpan
# Processing Record 3 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 5 of Set 1 | labrador city
# Processing Record 6 of Set 1 | alofi
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | qujing
# Processing Record 10 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | timimoun
# Processing Record 12 of Set 1 | tadine
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | opuwo
# Processing Record 15 of Set 1 | atafu village
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | miquelon
# Processing Record 18 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 19 of Set 1 | puerto natales
# Processing Record 20 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 21 of Set 1 | wailua homesteads
# Processing Record 22 of Set 1 | lawton
# Processing Record 23 of Set 1 | alice springs
# Processing Record 24 of Set 1 | saint-louis
# Processing Record 25 of Set 1 | fale old settlement
# Processing Record 26 of Set 1 | port-aux-francais
# Processing Record 27 of Set 1 | tevragh zeina
# City not found. Skipping...
# Processing Record 28 of Set 1 | okhotsk
# Processing Record 29 of Set 1 | nogliki
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | port mathurin
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | grytviken
# Processing Record 34 of Set 1 | manggar
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | misratah
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | malango
# Processing Record 40 of Set 1 | howrah
# Processing Record 41 of Set 1 | konstantinovka
# Processing Record 42 of Set 1 | blackmans bay
# Processing Record 43 of Set 1 | polyarnyy
# Processing Record 44 of Set 1 | queenstown
# Processing Record 45 of Set 1 | margaret river
# Processing Record 46 of Set 1 | hawaiian paradise park
# Processing Record 47 of Set 1 | lihue
# Processing Record 48 of Set 1 | olonkinbyen
# Processing Record 49 of Set 1 | san jose del guaviare
# Processing Record 50 of Set 1 | kodiak
# Processing Record 0 of Set 2 | copiapo
# Processing Record 1 of Set 2 | bayan nur
# City not found. Skipping...
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | ijuw
# City not found. Skipping...
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | tralee
# Processing Record 6 of Set 2 | roccella ionica
# Processing Record 7 of Set 2 | whakatane
# Processing Record 8 of Set 2 | kerikeri
# Processing Record 9 of Set 2 | itaituba
# Processing Record 10 of Set 2 | fukuecho
# Processing Record 11 of Set 2 | nema
# Processing Record 12 of Set 2 | mount pearl
# Processing Record 13 of Set 2 | vilyuchinsk
# Processing Record 14 of Set 2 | gudauri
# Processing Record 15 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 16 of Set 2 | gemena
# Processing Record 17 of Set 2 | kaisiadorys
# Processing Record 18 of Set 2 | la gi
# Processing Record 19 of Set 2 | utrik
# Processing Record 20 of Set 2 | touros
# Processing Record 21 of Set 2 | iskateley
# Processing Record 22 of Set 2 | khovd
# Processing Record 23 of Set 2 | kamiiso
# Processing Record 24 of Set 2 | egilsstadir
# Processing Record 25 of Set 2 | mejit
# Processing Record 26 of Set 2 | cova figueira
# Processing Record 27 of Set 2 | ilulissat
# Processing Record 28 of Set 2 | brookings
# Processing Record 29 of Set 2 | constantia
# Processing Record 30 of Set 2 | nizhneudinsk
# Processing Record 31 of Set 2 | badger
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | gates-north gates
# City not found. Skipping...
# Processing Record 34 of Set 2 | san jose de guanipa
# Processing Record 35 of Set 2 | santa cruz
# Processing Record 36 of Set 2 | kavkazskaya
# Processing Record 37 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 38 of Set 2 | baruun-urt
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | uliastay
# Processing Record 41 of Set 2 | flying fish cove
# Processing Record 42 of Set 2 | neyriz
# Processing Record 43 of Set 2 | sitka
# Processing Record 44 of Set 2 | great bend
# Processing Record 45 of Set 2 | tazacorte
# Processing Record 46 of Set 2 | rongelap
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | abraham's bay
# City not found. Skipping...
# Processing Record 40 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 41 of Set 4 | chom thong
# Processing Record 42 of Set 4 | bamboo flat
# Processing Record 43 of Set 4 | amga
# Processing Record 44 of Set 4 | isyangulovo
# Processing Record 45 of Set 4 | tinogasta
# Processing Record 46 of Set 4 | brisas de zicatela
# Processing Record 47 of Set 4 | ulladulla
# Processing Record 48 of Set 4 | penzance
# Processing Record 49 of Set 4 | goundam
# Processing Record 0 of Set 5 | sheregesh
# Processing Record 1 of Set 5 | gwarzo
# Processing Record 2 of Set 5 | diego de almagro
# Processing Record 3 of Set 5 | bozova
# Processing Record 4 of Set 5 | lianyuan
# Processing Record 5 of Set 5 | bikenibeu village
# Processing Record 6 of Set 5 | east london
# Processing Record 7 of Set 5 | nikolayevsk-on-amure
# Processing Record 8 of Set 5 | nemuro
# Processing Record 9 of Set 5 | minas de marcona
# Processing Record 10 of Set 5 | mayya
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | nahiyat al fuhud
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | fort bragg
# Processing Record 15 of Set 5 | cadale
# Processing Record 16 of Set 5 | margate
# Processing Record 17 of Set 5 | new norfolk
# Processing Record 18 of Set 5 | kruisfontein
# Processing Record 19 of Set 5 | taro
# Processing Record 20 of Set 5 | dunedin
# Processing Record 21 of Set 5 | ephrata
# Processing Record 22 of Set 5 | anadyr
# Processing Record 23 of Set 5 | sovetsk
# Processing Record 24 of Set 5 | mezhdurechenskiy
# Processing Record 25 of Set 5 | xinzhi
# Processing Record 26 of Set 5 | thompson
# Processing Record 27 of Set 5 | nakambala
# Processing Record 28 of Set 5 | kaiapoi
# Processing Record 29 of Set 5 | ixtapa
# Processing Record 30 of Set 5 | tiksi
# Processing Record 31 of Set 5 | sabang
# Processing Record 32 of Set 5 | baotou
# Processing Record 33 of Set 5 | namibe
# Processing Record 34 of Set 5 | ringkobing
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | remire-montjoly
# Processing Record 37 of Set 5 | hashtpar
# Processing Record 38 of Set 5 | laguna
# Processing Record 39 of Set 5 | ca mau
# Processing Record 40 of Set 5 | quellon
# Processing Record 41 of Set 5 | praia da vitoria
# Processing Record 42 of Set 5 | gaozhou
# Processing Record 43 of Set 5 | kill devil hills
# Processing Record 44 of Set 5 | port isabel
# Processing Record 45 of Set 5 | caranan
# Processing Record 46 of Set 5 | salinopolis
# Processing Record 47 of Set 5 | saguenay
# Processing Record 48 of Set 5 | songea
# Processing Record 49 of Set 5 | qarqaraly
# Processing Record 0 of Set 6 | akureyri
# Processing Record 1 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 2 of Set 6 | ola
# Processing Record 3 of Set 6 | dudinka
# Processing Record 4 of Set 6 | ciudad cuauhtemoc
# Processing Record 5 of Set 6 | panguma
# Processing Record 6 of Set 6 | shahin dezh
# Processing Record 7 of Set 6 | cabedelo
# Processing Record 8 of Set 6 | dothan
# Processing Record 9 of Set 6 | rosario del tala
# Processing Record 10 of Set 6 | ordubad
# Processing Record 11 of Set 6 | isafjordur
# Processing Record 12 of Set 6 | rio grande
# Processing Record 13 of Set 6 | zouerate
# Processing Record 14 of Set 6 | arraial do cabo
# Processing Record 15 of Set 6 | murghob
# Processing Record 16 of Set 6 | aykhal
# Processing Record 17 of Set 6 | christchurch
# Processing Record 18 of Set 6 | lebu
# Processing Record 19 of Set 6 | amlapura city
# City not found. Skipping...
# Processing Record 20 of Set 6 | beitbridge
# Processing Record 21 of Set 6 | urengoy
# Processing Record 22 of Set 6 | priozersk
# Processing Record 23 of Set 6 | fort st. john
# Processing Record 24 of Set 6 | norfolk
# Processing Record 25 of Set 6 | kotlas
# Processing Record 26 of Set 6 | sao joao da barra
# Processing Record 27 of Set 6 | kenai
# Processing Record 28 of Set 6 | honfleur
# Processing Record 29 of Set 6 | nizhniy kuranakh
# Processing Record 30 of Set 6 | funadhoo
# Processing Record 31 of Set 6 | thunder bay
# Processing Record 32 of Set 6 | port alfred
# Processing Record 33 of Set 6 | qaqortoq
# Processing Record 34 of Set 6 | yangor
# City not found. Skipping...
# Processing Record 35 of Set 6 | stanley
# Processing Record 36 of Set 6 | shadegan
# Processing Record 37 of Set 6 | lompoc
# Processing Record 38 of Set 6 | guerrero negro
# Processing Record 39 of Set 6 | agadez
# Processing Record 40 of Set 6 | alotau
# Processing Record 41 of Set 6 | baikunthpur
# Processing Record 42 of Set 6 | robertsport
# Processing Record 43 of Set 6 | tazovsky
# Processing Record 44 of Set 6 | sao tome
# Processing Record 45 of Set 6 | reynoldsburg
# Processing Record 46 of Set 6 | sandnessjoen
# Processing Record 47 of Set 6 | jeremie
# Processing Record 48 of Set 6 | visakhapatnam
# Processing Record 49 of Set 6 | george town
# Processing Record 0 of Set 7 | nuku'alofa
# Processing Record 1 of Set 7 | boa vista
# Processing Record 2 of Set 7 | bismarck
# Processing Record 3 of Set 7 | afaahiti
# Processing Record 4 of Set 7 | bandar lampung
# Processing Record 5 of Set 7 | pathein
# Processing Record 6 of Set 7 | hongch'on
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | dul'durga
# Processing Record 9 of Set 7 | hell-ville
# Processing Record 10 of Set 7 | port blair
# Processing Record 11 of Set 7 | bel ombre
# Processing Record 12 of Set 7 | palu
# Processing Record 13 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 14 of Set 7 | guiuan
# Processing Record 15 of Set 7 | tekeli
# Processing Record 16 of Set 7 | tsiombe
# Processing Record 17 of Set 7 | luganville
# Processing Record 18 of Set 7 | howard springs
# Processing Record 19 of Set 7 | villa gesell
# Processing Record 20 of Set 7 | maceio
# Processing Record 21 of Set 7 | zaozersk
# Processing Record 22 of Set 7 | natal
# Processing Record 23 of Set 7 | bechar
# Processing Record 24 of Set 7 | irbit
# Processing Record 25 of Set 7 | mata-utu
# Processing Record 26 of Set 7 | oneonta
# Processing Record 27 of Set 7 | kupang
# Processing Record 28 of Set 7 | rovnoye
# Processing Record 29 of Set 7 | dryden
# Processing Record 30 of Set 7 | viitasaari
# Processing Record 31 of Set 7 | cabeza del buey
# Processing Record 32 of Set 7 | puerto carreno
# Processing Record 33 of Set 7 | murzuq
# Processing Record 34 of Set 7 | yuzhno-kurilsk
# Processing Record 35 of Set 7 | holdrege
# Processing Record 36 of Set 7 | baie-saint-paul
# Processing Record 37 of Set 7 | magadan
# Processing Record 38 of Set 7 | yaren
# Processing Record 39 of Set 7 | kirillov
# Processing Record 40 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 41 of Set 7 | zalingei
# Processing Record 42 of Set 7 | balabac
# Processing Record 43 of Set 7 | kapuskasing
# Processing Record 44 of Set 7 | san luis de la loma
# Processing Record 45 of Set 7 | monteagudo
# Processing Record 46 of Set 7 | zakamensk
# Processing Record 47 of Set 7 | peterhead
# Processing Record 48 of Set 7 | asau
# Processing Record 49 of Set 7 | crane
# Processing Record 0 of Set 8 | nuuk
# Processing Record 1 of Set 8 | kattivakkam
# Processing Record 2 of Set 8 | rawson
# Processing Record 3 of Set 8 | laascaanood
# Processing Record 4 of Set 8 | parapat
# Processing Record 5 of Set 8 | khandyga
# Processing Record 6 of Set 8 | lobujya
# Processing Record 7 of Set 8 | batticaloa
# Processing Record 8 of Set 8 | arish
# Processing Record 9 of Set 8 | makarov
# Processing Record 10 of Set 8 | selfoss
# Processing Record 45 of Set 9 | ponta delgada
# Processing Record 46 of Set 9 | alpine
# Processing Record 47 of Set 9 | belyy yar
# Processing Record 48 of Set 9 | jaumave
# Processing Record 49 of Set 9 | xique xique
# Processing Record 0 of Set 10 | batavia
# Processing Record 1 of Set 10 | dubbo
# Processing Record 2 of Set 10 | al hazm
# Processing Record 3 of Set 10 | swift current
# Processing Record 4 of Set 10 | ha'il
# Processing Record 5 of Set 10 | horta
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | cape coast
# Processing Record 8 of Set 10 | vicksburg
# Processing Record 9 of Set 10 | taveta
# Processing Record 10 of Set 10 | bairnsdale
# Processing Record 11 of Set 10 | santa elena de uairen
# Processing Record 12 of Set 10 | trujillo
# Processing Record 13 of Set 10 | axim
# Processing Record 14 of Set 10 | belton
# Processing Record 15 of Set 10 | colonia
# Processing Record 16 of Set 10 | fier
# Processing Record 17 of Set 10 | namtsy
# Processing Record 18 of Set 10 | altos del rosario
# Processing Record 19 of Set 10 | bryne
# Processing Record 20 of Set 10 | murray bridge
# Processing Record 21 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 22 of Set 10 | portland
# Processing Record 23 of Set 10 | las lomitas
# Processing Record 24 of Set 10 | molde
# Processing Record 25 of Set 10 | alenquer
# Processing Record 26 of Set 10 | susuman
# Processing Record 27 of Set 10 | gazojak
# Processing Record 28 of Set 10 | suai
# City not found. Skipping...
# Processing Record 29 of Set 10 | ishigaki
# Processing Record 30 of Set 10 | corner brook
# Processing Record 31 of Set 10 | happy valley-goose bay
# Processing Record 32 of Set 10 | sebin karahisar
# Processing Record 33 of Set 10 | ginir
# Processing Record 34 of Set 10 | tirat karmel
# Processing Record 35 of Set 10 | zhanibek
# Processing Record 36 of Set 10 | claudio
# Processing Record 37 of Set 10 | ust'-charyshskaya pristan'
# Processing Record 38 of Set 10 | prince rupert
# Processing Record 39 of Set 10 | pariaman
# Processing Record 40 of Set 10 | tosontsengel
# Processing Record 41 of Set 10 | suolahti
# Processing Record 42 of Set 10 | pisco
# Processing Record 43 of Set 10 | greenville
# Processing Record 44 of Set 10 | mount isa
# Processing Record 45 of Set 10 | luderitz
# Processing Record 46 of Set 10 | makoua
# Processing Record 47 of Set 10 | tot'ma
# Processing Record 48 of Set 10 | eydhafushi
# Processing Record 49 of Set 10 | newman
# Processing Record 0 of Set 11 | nili
# Processing Record 1 of Set 11 | kapa'a
# Processing Record 2 of Set 11 | mitu
# Processing Record 3 of Set 11 | kununurra
# Processing Record 4 of Set 11 | barra do bugres
# Processing Record 5 of Set 11 | botucatu
# Processing Record 6 of Set 11 | naze
# Processing Record 7 of Set 11 | taoudenni
# Processing Record 8 of Set 11 | karaton
# Processing Record 9 of Set 11 | puerto ayacucho
# Processing Record 10 of Set 11 | gorom-gorom
# Processing Record 11 of Set 11 | recani
# Processing Record 12 of Set 11 | novyy urgal
# Processing Record 13 of Set 11 | oriximina
# Processing Record 14 of Set 11 | udgir
# Processing Record 15 of Set 11 | banff
# Processing Record 16 of Set 11 | pakxan
# Processing Record 17 of Set 11 | halikko
# Processing Record 18 of Set 11 | barrancabermeja
# Processing Record 19 of Set 11 | la ronge
# Processing Record 20 of Set 11 | reuleuet
# Processing Record 21 of Set 11 | whyalla stuart
# City not found. Skipping...
# Processing Record 22 of Set 11 | andalgala
# Processing Record 23 of Set 11 | nova vicosa
# Processing Record 24 of Set 11 | port macquarie
# Processing Record 25 of Set 11 | la palma
# Processing Record 26 of Set 11 | vila franca do campo
# Processing Record 27 of Set 11 | trairi
# Processing Record 28 of Set 11 | as salamiyah
# Processing Record 29 of Set 11 | castillos
# Processing Record 30 of Set 11 | el granada
# Processing Record 31 of Set 11 | kirensk
# Processing Record 32 of Set 11 | kangar
# Processing Record 33 of Set 11 | orchard homes
# Processing Record 34 of Set 11 | gorontalo
# Processing Record 35 of Set 11 | negru voda
# Processing Record 36 of Set 11 | shache
# Processing Record 37 of Set 11 | lorengau
# Processing Record 38 of Set 11 | moyale
# Processing Record 39 of Set 11 | bom jesus
# Processing Record 40 of Set 11 | buenaventura
# Processing Record 41 of Set 11 | harar
# Processing Record 42 of Set 11 | lys'va
# Processing Record 43 of Set 11 | as sulayyil
# Processing Record 44 of Set 11 | ancud
# Processing Record 45 of Set 11 | runing
# Processing Record 46 of Set 11 | baukau
# Processing Record 47 of Set 11 | 'ain el hadjar
# Processing Record 48 of Set 11 | slave lake
# Processing Record 49 of Set 11 | nova aurora
# Processing Record 0 of Set 12 | saksaul'skiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | mantua
# Processing Record 2 of Set 12 | gamba
# Processing Record 3 of Set 12 | coquimbo
# Processing Record 4 of Set 12 | al muwayh
# Processing Record 5 of Set 12 | gilgit
# Processing Record 6 of Set 12 | magdagachi
# Processing Record 7 of Set 12 | callao
# Processing Record 8 of Set 12 | mont-dore
# Processing Record 9 of Set 12 | ferozepore
# Processing Record 10 of Set 12 | phan rang-thap cham
# Processing Record 11 of Set 12 | arteche
# Processing Record 12 of Set 12 | salalah
# Processing Record 13 of Set 12 | merritt
# Processing Record 14 of Set 12 | port glaud
# City not found. Skipping...
# Processing Record 15 of Set 12 | nyrob
# Processing Record 16 of Set 12 | maitum
# Processing Record 17 of Set 12 | borodulikha
# Processing Record 18 of Set 12 | tobruk
# Processing Record 19 of Set 12 | mizdah
# Processing Record 20 of Set 12 | pandan
# Processing Record 21 of Set 12 | obihiro
# Processing Record 22 of Set 12 | looe
# Processing Record 23 of Set 12 | necochea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          551
# Lat           551
# Lng           551
# Max Temp      551
# Humidity      551
# Cloudiness    551
# Wind Speed    551
# Country       551
# Date          551
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       waitangi -43.9535 -176.5597     14.34        98         100
# 1         turpan  42.9333   89.1667     15.22        37          98
# 2  labrador city  52.9463  -66.9114      0.10        90         100
# 3          alofi -19.0595 -169.9187     25.94        78          75
# 4      adamstown -25.0660 -130.1015     20.05        91         100
#
#    Wind Speed Country        Date
# 0        5.36      NZ  1729986156
# 1        2.01      CN  1729986157
# 2       31.74      CA  1729986160
# 3        5.66      NU  1729986162
# 4        6.83      PN  1729986163

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             waitangi -43.9535 -176.5597     14.34        98         100
# 1               turpan  42.9333   89.1667     15.22        37          98
# 2        labrador city  52.9463  -66.9114      0.10        90         100
# 3                alofi -19.0595 -169.9187     25.94        78          75
# 4            adamstown -25.0660 -130.1015     20.05        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.36      NZ  1729986156
# 1              2.01      CN  1729986157
# 2             31.74      CA  1729986160
# 3              5.66      NU  1729986162
# 4              6.83      PN  1729986163

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Went back to the top to import datetime to allow this and the next
# Plots to have the current date as shown in the examples, made a variable to call it
# In a formatted string 
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], facecolor="blue", edgecolor="black", linewidths=1, marker="o", alpha=0.8)
date = datetime.today().date()

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], facecolor="blue", edgecolor="black", linewidths=1, marker="o", alpha=0.8)
date = datetime.today().date()

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], facecolor="blue", edgecolor="black", linewidths=1, marker="o", alpha=0.8)
date = datetime.today().date()


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], facecolor="blue", edgecolor="black", linewidths=1, marker="o", alpha=0.8)
date = datetime.today().date()


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Used the following as references: https://docs.scipy.org/doc/scipy/reference/
# generated/scipy.stats.linregress.html, https://matplotlib.org/stable/tutorials/pyplot.html
def plot_linear_regression(x_values, y_values, x_label, y_label, title):
    slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)
    plt.scatter(x_values, y_values, edgecolor="black", facecolor="blue", alpha=0.8)

    regress_values = slope * x_values + intercept
    plt.plot(x_values, regress_values, "r-")

    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

    r_squared = r_value**2
    plt.text(min(x_values), min(y_values),
             f"y = {slope:.2f}x + {intercept:.2f}",
            fontsize=10, color="red")
    print("The r2-value is:", r_squared)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               turpan  42.9333   89.1667     15.22        37          98
# 2        labrador city  52.9463  -66.9114      0.10        90         100
# 5           georgetown   5.4112  100.3354     25.96        88          40
# 6               qujing  25.4833  103.7833     11.64        79         100
# 8             timimoun  29.2639    0.2310     22.21        35           0
#
#          Wind Speed Country        Date
# City_ID
# 1              2.01      CN  1729986157
# 2             31.74      CA  1729986160
# 5              2.06      MY  1729986143
# 6              2.61      CN  1729986165
# 8              4.12      DZ  1729986168

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           waitangi -43.9535 -176.5597     14.34        98
# 3                              alofi -19.0595 -169.9187     25.94        78
# 4                          adamstown -25.0660 -130.1015     20.05        91
# 7        edinburgh of the seven seas -37.0676  -12.3116     15.75        95
# 9                             tadine -21.5500  167.8833     25.71        64
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        5.36      NZ  1729986156
# 3                75        5.66      NU  1729986162
# 4               100        6.83      PN  1729986163
# 7               100       11.53      SH  1729986167
# 9               100        5.49      NC  1729986169

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Max Temp"],
                       "Latitude",
                       "Max Temp (C)",
                       "Northern Hemisphere: Latitude vs. Max Temp")
# Out:
# The r2-value is: 0.7253069693780374

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Max Temp"],
                       "Latitude",
                       "Max Temp (C)",
                       "Southern Hemisphere: Latitude vs. Max Temp")
# Out:
# The r2-value is: 0.6070554033907913

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Humidity"],
                       "Latitude",
                       "Humidity (%)",
                       "Northern Hemisphere: Latitude vs. Humidity")
# Out:
# The r2-value is: 0.020770274304253194

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Humidity"],
                       "Latitude",
                       "Humidity (%)",
                       "Southern Hemisphere: Latitude vs. Humidity")
# Out:
# The r2-value is: 0.005892759574459925

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Cloudiness"],
                       "Latitude",
                       "Cloudiness",
                       "Northern Hemisphere: Latitude vs. Cloudiness")
# Out:
# The r2-value is: 0.015913485442014045

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Cloudiness"],
                       "Latitude",
                       "Cloudiness",
                       "Southern Hemisphere: Latitude vs. Cloudiness")
# Out:
# The r2-value is: 0.007907702344213152

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Wind Speed"],
                       "Latitude",
                       "Wind Speed",
                       "Northern Hemisphere: Latitude vs. Wind Speed")
# Out:
# The r2-value is: 0.004903547868030799

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Wind Speed"],
                       "Latitude",
                       "Wind Speed",
                       "Southern Hemisphere: Latitude vs. Wind Speed")
# Out:
# The r2-value is: 0.03300734070382435

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
